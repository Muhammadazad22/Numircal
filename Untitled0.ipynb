# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammadazad22/Numircal/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

def bisection_method(func, a, b, tol=1e-6, max_iter=100):
    x = sp.symbols('x')
    func_sym = sp.sympify(func)

    if func_sym.subs(x, a) * func_sym.subs(x, b) > 0:
        raise ValueError("The function values at the interval endpoints must have opposite signs.")

    import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

def bisection_method(func, a, b, tol=1e-6, max_iter=100):
    x = sp.symbols('x')
    func_sym = sp.sympify(func)

    if func_sym.subs(x, a) * func_sym.subs(x, b) > 0:
        raise ValueError("The function values at the interval endpoints must have opposite signs.")

    root = None
    iterations = 0
    errors = []

    print(f"\nBisection Method Iterations:")
    print(f"{'Iteration':<15}{'a':<15}{'b':<15}{'c':<15}{'f(c)':<15}{'Error':<15}")

    while (b - a) / 2 > tol and iterations < max_iter:
        c = (a + b) / 2
        error = abs(func_sym.subs(x, c))
        errors.append(error)

        print(f"{iterations + 1:<15}{a:<15.6f}{b:<15.6f}{c:<15.6f}{func_sym.subs(x, c):<15.6e}{error:<15.6e}")

        if func_sym.subs(x, c) == 0:
            root = c
            break
        elif func_sym.subs(x, c) * func_sym.subs(x, a) < 0:
            b = c
        else:
            a = c

        iterations += 1

    root = (a + b) / 2
    return root, iterations, errors

def plot_convergence(errors, log_scale=True, show_plot=True):
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(errors) + 1), errors, marker='o', linestyle='-', color='b')

    if log_scale:
        plt.yscale('log')

    plt.title('Convergence of Bisection Method')
    plt.xlabel('Iterations')
    plt.ylabel('Absolute Error')
    plt.grid(True)

    if show_plot:
        plt.show()

def main():
    # User interaction for providing the function and initial interval
    try:
        # Example usage: x**2 - 4
        func_str = input("Enter the function in terms of 'x' (e.g., x**2 - 4): ")
        a = float(input("Enter the lower bound of the interval (a): "))
        b = float(input("Enter the upper bound of the interval (b): "))

        # Find the root using the Bisection method
        root, iterations, errors = bisection_method(func_str, a, b)

        # Print the result
        print(f"\nRoot: {root}")
        print(f"Iterations: {iterations}")

        # Plot convergence
        log_scale = input("Do you want to plot with a logarithmic scale? (y/n): ").lower() == 'y'
        show_plot = input("Do you want to display the plot? (y/n): ").lower() == 'y'
        plot_convergence(errors, log_scale=log_scale, show_plot=show_plot)

    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Enter the function in terms of 'x' (e.g., x**2 - 4): x**3 - 2*x - 5
# Enter the lower bound of the interval (a): 1
# Enter the upper bound of the interval (b): 3
#
# Bisection Method Iterations:
# Iteration      a              b              c              f(c)           Error
# 1              1.000000       3.000000       2.000000       -1.000000e+0   1.000000e+0
# 2              2.000000       3.000000       2.500000       5.625000e+0    5.625000e+0
# 3              2.000000       2.500000       2.250000       1.890625e+0    1.890625e+0
# 4              2.000000       2.250000       2.125000       3.457031e-1    3.457031e-1
# 5              2.000000       2.125000       2.062500       -3.513184e-1   3.513184e-1
# 6              2.062500       2.125000       2.093750       -8.941650e-3   8.941650e-3
# 7              2.093750       2.125000       2.109375       1.668358e-1    1.668358e-1
# 8              2.093750       2.109375       2.101562       7.856226e-2    7.856226e-2
# ...
